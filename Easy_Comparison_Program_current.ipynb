# %%
from sklearn.datasets import make_regression, make_classification, make_blobs
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import time
from Gaussian_process_current import GaussianProcess, SparseGaussianProcess

# %%
# Generate synthetic regression dat
n_samples, n_features, noise = 1000, 2, 0.1
X, y = make_regression(n_samples=n_samples, n_features=n_features)

# Plot the first two dimensions of the data
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', s=10)
plt.title('Synthetic Regression Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar(label='Target Value')
plt.show()

# %%
def estimate_memory_usage(n_samples, n_features, model_type, n_inducing=None):
    # Memory for dataset (X_train and y_train)
    dataset_memory = n_samples * n_features * 8 + n_samples * 8  # X_train + y_train (float64, 8 bytes per float)
    if model_type == "GPR":
        # Full GP: Covariance matrix is N x N
        covariance_matrix_memory = n_samples ** 2 * 8  # N x N matrix, 8 bytes per float
    elif model_type == "SGPR":
        # Sparse GP: Covariance matrix is M x M (inducing points)
        if n_inducing is None:
            raise ValueError("n_inducing must be provided for SGPR")
        covariance_matrix_memory = n_inducing ** 2 * 8  # M x M matrix, 8 bytes per float
    
    # Memory for kernel parameters and gradients (assume around 1 KB for kernel + gradients)
    kernel_and_gradients_memory = 1024  # Rough estimation

    # Total memory usage estimate
    total_memory = dataset_memory + covariance_matrix_memory + kernel_and_gradients_memory

    return total_memory / (1024 ** 2)  # Convert to MB

# %%
# Function to train a GP model and return the RMSE, average uncertainty, time taken, and iteration count
def train_and_evaluate_gp(n_samples, model, optim_method):
    # Generate synthetic regression data
    X, y = make_regression(n_samples=n_samples, n_features=1, noise=0.1, random_state=0)  # n_features=1 for plotting
    # Split the data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # Create a GP regression model with an RBF kernel
    ''' if model == "GPR":
        model = gpf.models.GPR(data=(X_train, y_train), kernel=Kernel, mean_function=None)
    elif model == "SGPR":
        inducing_variables = tf.gather(X_train, tf.random.shuffle(tf.range(tf.shape(X_train)[0]))[:tf.shape(X_train)[0] // 10])
        model = gpf.models.SGPR(data=(X_train, y_train), kernel=Kernel, inducing_variable=inducing_variables, mean_function=None)
        gpf.config.set_default_jitter(1e-6) '''
    # Measure the time taken to optimize (which includes matrix inversion)
    start_time = time.time()
    
    # Optimize the model's parameters with a callback to count iterations
    if model == "GPR":
        model = GaussianProcess(X_train, y_train, optim_method)
    if model == "SGPR":
        n_inducing_points = int(len(X_train)*0.1)  # 10% of training points
        Z_train = X_train[np.random.choice(len(X_train), n_inducing_points, replace=False)]
        model = SparseGaussianProcess(X_train, y_train,Z_train, optim_method)
    
    model.fit()
    
    
    end_time = time.time()
    
    # Time taken for matrix inversion and optimization
    time_taken = end_time - start_time
    
    # Retrieve and display parameter history if optimizer is ADAM
    if hasattr(model, "adam_optimizer"):
        param_history = model.adam_optimizer.param_history
        print("Parameter History:")
        #for params in param_history:
        #    print(params)
    
    # Make predictions on the test set
    means, variances = zip(*(model.predict(x.reshape(-1, 1)) for x in X_test))

    # Compute RMSE
    rmse = np.sqrt(np.mean((np.array(means) - y_test) ** 2))

    # Compute average uncertainty (standard deviation)
    avg_uncertainty = np.mean(np.sqrt(np.array(variances)))
    
    return rmse, avg_uncertainty, time_taken

# %%
import matplotlib.pyplot as plt
import numpy as np
import psutil
import time

# Utility to get memory usage
def get_memory_usage():
    process = psutil.Process()
    mem_info = process.memory_info()
    return mem_info.rss / (1024 ** 2)  # Return memory usage in MB

# General function to run comparison for multiple GP models
def run_comparison(max_samples, models_kernels):
    start = 20
    step = 10
    dataset_sizes = np.arange(start, max_samples + 1, step)

    # Dictionary to store results for each model
    results = {
        'loss_history': {},
        'times': {},
        'uncertainties': {},
        'memory_usages': {},
    }

    # Loop over each model and its kernel
    for model_name, optim_method in models_kernels:
        loss_history = []
        times = []
        uncertainties = []  
        memory_usages = []
        


        for idx, size in enumerate(dataset_sizes):
            rmse, avg_uncertainty, time_taken = train_and_evaluate_gp(size, model_name, optim_method)
            loss_history.append(rmse)
            memory = estimate_memory_usage(n_samples=size, n_features=n_features, model_type=model_name, n_inducing=0.1*size)
            uncertainties.append(avg_uncertainty)
            times.append(time_taken)
            memory_usages.append(memory)
            name = model_name + " " + optim_method
            print(f"Model: {name}, Dataset size: {size}, Time: {time_taken:.4f} seconds, "
                  f"Memory: {memory:.2f} MB,"
                  f"Uncertainty: {avg_uncertainty:.4f}")
        
        # Store results for this model
        results['times'][name] = times
        results['uncertainties'][name] = uncertainties
        results['memory_usages'][name] = memory_usages
        results['loss_history'][name] = loss_history
    
    # Plotting the results
    plt.figure(figsize=(10, 12))
    # Loss plot

    plt.subplot(4, 1, 1)
    for name in results['loss_history']:
        plt.plot(dataset_sizes, results['loss_history'][name], 'o-', label=f'{name} Loss')
    plt.title('Performance Metrics vs Dataset Size')
    plt.ylabel('Loss (RMSE)')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()
    
    # Time Plot
    plt.subplot(4, 1, 2)
    for name in results['times']:
        plt.plot(dataset_sizes, results['times'][name], 'o-', label=f'{name} Time')
    plt.title('Performance Metrics vs Dataset Size')
    plt.ylabel('Time (seconds)')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()

    # Memory Usage Plot
    plt.subplot(4, 1, 3)
    for name in results['memory_usages']:
        plt.plot(dataset_sizes, results['memory_usages'][name], 'o-', label=f'{name} Memory Usage')
    plt.ylabel('Memory Usage (MB)')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()

    # Uncertainty Plot
    plt.subplot(4, 1, 4)
    for name in results['uncertainties']:
        plt.plot(dataset_sizes, results['uncertainties'][name], 'o-', label=f'{name} Avg. Uncertainty')
    plt.ylabel('Uncertainty')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

    return results

# %%
models_kernels = [
    ("GPR", "L-BFGS-B"),
    ("SGPR", "L-BFGS-B"),
    ("GPR", "CG"),
    ("SGPR", "CG"),
    ("GPR", "ADAM"),
    ("SGPR", "ADAM"),
    

]
# Run the comparison for these models
run_comparison(max_samples=100, models_kernels=models_kernels)
# Out:
# Training complete. Optimal length scale: 0.56, Signal variance: 0.31, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 20, Time: 0.4742 seconds, Memory: 0.00 MB,Uncertainty: 0.0021
# Training complete. Optimal length scale: 1.82, Signal variance: 0.88, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 30, Time: 1.0745 seconds, Memory: 0.01 MB,Uncertainty: 0.0016
# Training complete. Optimal length scale: 1.49, Signal variance: 0.54, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 40, Time: 1.7912 seconds, Memory: 0.01 MB,Uncertainty: 0.0006
# Training complete. Optimal length scale: 0.50, Signal variance: 0.71, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 50, Time: 2.8844 seconds, Memory: 0.02 MB,Uncertainty: 0.0011
# Training complete. Optimal length scale: 1.60, Signal variance: 0.23, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 60, Time: 4.0289 seconds, Memory: 0.03 MB,Uncertainty: 0.0007
# Training complete. Optimal length scale: 1.57, Signal variance: 0.61, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 70, Time: 12.0877 seconds, Memory: 0.04 MB,Uncertainty: 0.0012
# Training complete. Optimal length scale: 1.89, Signal variance: 0.67, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 80, Time: 6.9013 seconds, Memory: 0.05 MB,Uncertainty: 0.0008
# Training complete. Optimal length scale: 1.16, Signal variance: 1.17, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 90, Time: 8.6417 seconds, Memory: 0.06 MB,Uncertainty: 0.0064
# Training complete. Optimal length scale: 0.85, Signal variance: 0.74, Noise variance: 0.00
# Model: GPR L-BFGS-B, Dataset size: 100, Time: 10.5802 seconds, Memory: 0.08 MB,Uncertainty: 0.0007
# Training complete. Optimal length scale: 0.84, Signal variance: 1.72, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 20, Time: 0.3252 seconds, Memory: 0.00 MB,Uncertainty: 0.6884
# Training complete. Optimal length scale: 1.52, Signal variance: 0.97, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 30, Time: 0.2509 seconds, Memory: 0.00 MB,Uncertainty: 0.2011
# Training complete. Optimal length scale: 0.92, Signal variance: 0.71, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 40, Time: 0.3844 seconds, Memory: 0.00 MB,Uncertainty: 0.3649
# Training complete. Optimal length scale: 1.50, Signal variance: 1.47, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 50, Time: 0.5406 seconds, Memory: 0.00 MB,Uncertainty: 0.0141
# Training complete. Optimal length scale: 0.26, Signal variance: 0.14, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 60, Time: 0.6362 seconds, Memory: 0.00 MB,Uncertainty: 0.5714
# Training complete. Optimal length scale: 0.32, Signal variance: 1.42, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 70, Time: 0.9862 seconds, Memory: 0.00 MB,Uncertainty: 0.7555
# Training complete. Optimal length scale: 0.74, Signal variance: 0.75, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 80, Time: 1.2234 seconds, Memory: 0.00 MB,Uncertainty: 0.0856
# Training complete. Optimal length scale: 0.20, Signal variance: 1.03, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 90, Time: 1.5299 seconds, Memory: 0.00 MB,Uncertainty: 0.6839
# Training complete. Optimal length scale: 0.96, Signal variance: 1.43, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 100, Time: 1.8820 seconds, Memory: 0.00 MB,Uncertainty: 0.0063
# Training complete. Optimal length scale: 1.17, Signal variance: 0.18, Noise variance: 0.00
# Model: GPR CG, Dataset size: 20, Time: 0.4107 seconds, Memory: 0.00 MB,Uncertainty: 0.0009
# Training complete. Optimal length scale: 1.30, Signal variance: 1.43, Noise variance: 0.00
# Model: GPR CG, Dataset size: 30, Time: 1.0315 seconds, Memory: 0.01 MB,Uncertainty: 0.0027
# Training complete. Optimal length scale: 0.95, Signal variance: 1.39, Noise variance: 0.00
# Model: GPR CG, Dataset size: 40, Time: 1.7716 seconds, Memory: 0.01 MB,Uncertainty: 0.0010
# Training complete. Optimal length scale: 0.23, Signal variance: 1.90, Noise variance: 0.00
# Model: GPR CG, Dataset size: 50, Time: 2.6817 seconds, Memory: 0.02 MB,Uncertainty: 0.0020
# Training complete. Optimal length scale: 0.39, Signal variance: 1.44, Noise variance: 0.00
# Model: GPR CG, Dataset size: 60, Time: 3.7348 seconds, Memory: 0.03 MB,Uncertainty: 0.0026
# Training complete. Optimal length scale: 1.94, Signal variance: 1.36, Noise variance: 0.00
# Model: GPR CG, Dataset size: 70, Time: 5.0429 seconds, Memory: 0.04 MB,Uncertainty: 0.0007
# Training complete. Optimal length scale: 1.30, Signal variance: 0.38, Noise variance: 0.00
# Model: GPR CG, Dataset size: 80, Time: 6.6213 seconds, Memory: 0.05 MB,Uncertainty: 0.0005
# Training complete. Optimal length scale: 1.40, Signal variance: 0.61, Noise variance: 0.00
# Model: GPR CG, Dataset size: 90, Time: 8.7736 seconds, Memory: 0.06 MB,Uncertainty: 0.0043
# Training complete. Optimal length scale: 1.40, Signal variance: 1.60, Noise variance: 0.00
# Model: GPR CG, Dataset size: 100, Time: 18.0144 seconds, Memory: 0.08 MB,Uncertainty: 0.0010
# Training complete. Optimal length scale: 0.99, Signal variance: 1.50, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 20, Time: 0.1224 seconds, Memory: 0.00 MB,Uncertainty: 0.7001
# Training complete. Optimal length scale: 0.43, Signal variance: 0.70, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 30, Time: 0.2324 seconds, Memory: 0.00 MB,Uncertainty: 0.5298
# Training complete. Optimal length scale: 0.71, Signal variance: 3.05, Noise variance: 0.28
# Model: SGPR CG, Dataset size: 40, Time: 0.3101 seconds, Memory: 0.00 MB,Uncertainty: 0.8420
# Training complete. Optimal length scale: 0.79, Signal variance: 0.45, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 50, Time: 0.4483 seconds, Memory: 0.00 MB,Uncertainty: 0.7542
# Training complete. Optimal length scale: 1.77, Signal variance: 1.56, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 60, Time: 0.6306 seconds, Memory: 0.00 MB,Uncertainty: 0.0972
# Training complete. Optimal length scale: 0.49, Signal variance: 0.68, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 70, Time: 0.8601 seconds, Memory: 0.00 MB,Uncertainty: 0.2556
# Training complete. Optimal length scale: 0.60, Signal variance: 0.69, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 80, Time: 1.1294 seconds, Memory: 0.00 MB,Uncertainty: 0.2415
# Training complete. Optimal length scale: 1.21, Signal variance: 1.66, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 90, Time: 1.5001 seconds, Memory: 0.00 MB,Uncertainty: 0.0651
# Training complete. Optimal length scale: 0.38, Signal variance: 0.12, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 100, Time: 1.7784 seconds, Memory: 0.00 MB,Uncertainty: 0.2447
# Training complete. Optimal length scale: 1.26, Signal variance: 7.42, Noise variance: 3.93
# Parameter History:
# Model: GPR ADAM, Dataset size: 20, Time: 5.0807 seconds, Memory: 0.00 MB,Uncertainty: 2.0612
# Training complete. Optimal length scale: 1.33, Signal variance: 5.64, Noise variance: 2.82
# Parameter History:
# Model: GPR ADAM, Dataset size: 30, Time: 10.5764 seconds, Memory: 0.01 MB,Uncertainty: 1.7573
# Training complete. Optimal length scale: 1.23, Signal variance: 1.83, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 40, Time: 22.1065 seconds, Memory: 0.01 MB,Uncertainty: 0.0340
# Training complete. Optimal length scale: 1.79, Signal variance: 0.41, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 50, Time: 47.6701 seconds, Memory: 0.02 MB,Uncertainty: 0.0331
# Training complete. Optimal length scale: 1.92, Signal variance: 1.44, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 60, Time: 136.5641 seconds, Memory: 0.03 MB,Uncertainty: 0.0339
# Training complete. Optimal length scale: 0.97, Signal variance: 1.34, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 70, Time: 188.3733 seconds, Memory: 0.04 MB,Uncertainty: 0.0348
# Training complete. Optimal length scale: 0.54, Signal variance: 0.48, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 80, Time: 355.9867 seconds, Memory: 0.05 MB,Uncertainty: 0.0363
# Training complete. Optimal length scale: 0.71, Signal variance: 0.86, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 90, Time: 638.4481 seconds, Memory: 0.06 MB,Uncertainty: 0.0686
# Training complete. Optimal length scale: 0.58, Signal variance: 0.63, Noise variance: 0.00
# Parameter History:
# Model: GPR ADAM, Dataset size: 100, Time: 1117.7068 seconds, Memory: 0.08 MB,Uncertainty: 0.0339
# Training complete. Optimal length scale: 0.77, Signal variance: 5.86, Noise variance: 1.94
# Parameter History:
# Model: SGPR ADAM, Dataset size: 20, Time: 1.7053 seconds, Memory: 0.00 MB,Uncertainty: 1.6360
# Training complete. Optimal length scale: 0.76, Signal variance: 6.17, Noise variance: 2.72
# Parameter History:
# Model: SGPR ADAM, Dataset size: 30, Time: 1.7512 seconds, Memory: 0.00 MB,Uncertainty: 1.8971
# Training complete. Optimal length scale: 0.43, Signal variance: 8.05, Noise variance: 4.27
# Parameter History:
# Model: SGPR ADAM, Dataset size: 40, Time: 1.9262 seconds, Memory: 0.00 MB,Uncertainty: 2.2576
# Training complete. Optimal length scale: 1.20, Signal variance: 7.31, Noise variance: 3.77
# Parameter History:
# Model: SGPR ADAM, Dataset size: 50, Time: 2.1526 seconds, Memory: 0.00 MB,Uncertainty: 2.0927
# Training complete. Optimal length scale: 0.04, Signal variance: 7.27, Noise variance: 3.67
# Parameter History:
# Model: SGPR ADAM, Dataset size: 60, Time: 2.3284 seconds, Memory: 0.00 MB,Uncertainty: 2.1519
# Training complete. Optimal length scale: 1.06, Signal variance: 6.11, Noise variance: 2.59
# Parameter History:
# Model: SGPR ADAM, Dataset size: 70, Time: 2.6562 seconds, Memory: 0.00 MB,Uncertainty: 1.7982
# Training complete. Optimal length scale: 0.01, Signal variance: 2.43, Noise variance: 0.55
# Parameter History:
# Model: SGPR ADAM, Dataset size: 80, Time: 3.0686 seconds, Memory: 0.00 MB,Uncertainty: 1.2460
# Training complete. Optimal length scale: 0.08, Signal variance: 7.42, Noise variance: 3.81
# Parameter History:
# Model: SGPR ADAM, Dataset size: 90, Time: 3.5078 seconds, Memory: 0.00 MB,Uncertainty: 2.1910
# Training complete. Optimal length scale: 1.04, Signal variance: 7.49, Noise variance: 3.87
# Parameter History:
# Model: SGPR ADAM, Dataset size: 100, Time: 4.0149 seconds, Memory: 0.00 MB,Uncertainty: 2.1118
# {'loss_history': {'GPR L-BFGS-B': [0.09680737123805902,
#    0.34491696533785865,
#    0.08754565507547388,
#    0.09562731891199822,
#    0.08887260807591126,
#    0.12589573934184747,
#    0.09872966972199022,
#    1.8409235505830648,
#    0.11394372652337958],
#   'SGPR L-BFGS-B': [13.024310107427565,
#    153.00257929563284,
#    103.71986388000597,
#    11.739200380580558,
#    163.1362519255623,
#    76.63921451774685,
#    126.07059174409657,
#    122.29209459928128,
#    64.79071042280188],
#   'GPR CG': [0.09843904487594496,
#    0.24844835401430382,
#    0.08634212137283347,
#    0.12223615117946869,
#    0.31996957822902367,
#    0.11046942699415283,
#    0.096493679612514,
#    0.9184449812458797,
#    0.108173697840767],
#   'SGPR CG': [6.263628013418378,
#    134.34306702532837,
#    42.197174352777125,
#    33.87003645718399,
#    597.78192381594,
#    82.72059636113217,
#    311.8884345378615,
#    3255.032024527885,
#    315.018768219],
#   'GPR ADAM': [6.018112832389531,
#    40.0044831966651,
#    0.14606985581989215,
#    0.09364016809439658,
#    0.22464120807924773,
#    0.5534931817161117,
#    0.43421688569803535,
#    20.777407970813005,
#    0.14270525345496032],
#   'SGPR ADAM': [12.212240200730122,
#    126.20874042975281,
#    26.411166720695743,
#    10.946199055834523,
#    35.81472042510106,
#    56.662303160120146,
#    89.47398251702444,
#    90.55010890971198,
#    45.09579960318238]},
#  'times': {'GPR L-BFGS-B': [0.47423887252807617,
#    1.0744760036468506,
#    1.7912049293518066,
#    2.884373903274536,
#    4.0288848876953125,
#    12.087660074234009,
#    6.901264905929565,
#    8.641685962677002,
#    10.580193996429443],
#   'SGPR L-BFGS-B': [0.32521510124206543,
#    0.2509040832519531,
#    0.38436198234558105,
#    0.5406479835510254,
#    0.6362118721008301,
#    0.9861660003662109,
#    1.2233819961547852,
#    1.529906988143921,
#    1.881972074508667],
#   'GPR CG': [0.41068482398986816,
#    1.031548261642456,
#    1.771578073501587,
#    2.681678056716919,
#    3.73480224609375,
#    5.042917966842651,
#    6.6212921142578125,
#    8.77357292175293,
#    18.014352798461914],
#   'SGPR CG': [0.12241005897521973,
#    0.2323756217956543,
#    0.31006479263305664,
#    0.44830989837646484,
#    0.6305868625640869,
#    0.8600599765777588,
#    1.129384994506836,
#    1.5000998973846436,
#    1.7783758640289307],
#   'GPR ADAM': [5.080651044845581,
#    10.576400756835938,
#    22.106479167938232,
#    47.67012882232666,
#    136.56405687332153,
#    188.3733081817627,
#    355.986713886261,
#    638.4480662345886,
#    1117.7067649364471],
#   'SGPR ADAM': [1.705336093902588,
#    1.7511909008026123,
#    1.9261939525604248,
#    2.1526169776916504,
#    2.3283939361572266,
#    2.6562271118164062,
#    3.068553924560547,
#    3.507765054702759,
#    4.014921188354492]},
#  'uncertainties': {'GPR L-BFGS-B': [0.002112678,
#    0.0015980435,
#    0.0005597313,
#    0.0011454469,
#    0.00069719047,
#    0.0011944372,
#    0.0008121964,
#    0.006442452,
#    0.00072333624],
#   'SGPR L-BFGS-B': [0.6883831,
#    0.20105667,
#    0.3649348,
#    0.014067447,
#    0.5713573,
#    0.75545174,
#    0.08563526,
#    0.6839396,
#    0.006256596],
#   'GPR CG': [0.00094976823,
#    0.0026664224,
#    0.0010409739,
#    0.0020253467,
#    0.0025973995,
#    0.00073051994,
#    0.00053471175,
#    0.0042575886,
#    0.0009968951],
#   'SGPR CG': [0.700135,
#    0.5297856,
#    0.8419868,
#    0.754221,
#    0.09716908,
#    0.2556451,
#    0.24145377,
#    0.06509051,
#    0.24471872],
#   'GPR ADAM': [2.0612123,
#    1.7572689,
#    0.034010924,
#    0.033102173,
#    0.033936653,
#    0.034824725,
#    0.036317363,
#    0.06863958,
#    0.0338812],
#   'SGPR ADAM': [1.6360091,
#    1.8970872,
#    2.2575817,
#    2.0927374,
#    2.1519165,
#    1.7981809,
#    1.2459894,
#    2.1910353,
#    2.1118383]},
#  'memory_usages': {'GPR L-BFGS-B': [0.004486083984375,
#    0.0085296630859375,
#    0.01409912109375,
#    0.0211944580078125,
#    0.029815673828125,
#    0.0399627685546875,
#    0.0516357421875,
#    0.0648345947265625,
#    0.079559326171875],
#   'SGPR L-BFGS-B': [0.00146484375,
#    0.00173187255859375,
#    0.00201416015625,
#    0.00231170654296875,
#    0.00262451171875,
#    0.00295257568359375,
#    0.0032958984375,
#    0.00365447998046875,
#    0.0040283203125],
#   'GPR CG': [0.004486083984375,
#    0.0085296630859375,
#    0.01409912109375,
#    0.0211944580078125,
#    0.029815673828125,
#    0.0399627685546875,
#    0.0516357421875,
#    0.0648345947265625,
#    0.079559326171875],
#   'SGPR CG': [0.00146484375,
#    0.00173187255859375,
#    0.00201416015625,
#    0.00231170654296875,
#    0.00262451171875,
#    0.00295257568359375,
#    0.0032958984375,
#    0.00365447998046875,
#    0.0040283203125],
#   'GPR ADAM': [0.004486083984375,
#    0.0085296630859375,
#    0.01409912109375,
#    0.0211944580078125,
#    0.029815673828125,
#    0.0399627685546875,
#    0.0516357421875,
#    0.0648345947265625,
#    0.079559326171875],
#   'SGPR ADAM': [0.00146484375,
#    0.00173187255859375,
#    0.00201416015625,
#    0.00231170654296875,
#    0.00262451171875,
#    0.00295257568359375,
#    0.0032958984375,
#    0.00365447998046875,
#    0.0040283203125]}}
