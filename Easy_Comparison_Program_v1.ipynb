# %%
from sklearn.datasets import make_regression, make_classification, make_blobs
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp
import tensorflow as tf
import time
from Gaussian_process_current import GaussianProcess, SparseGaussianProcess

# %%
# Generate synthetic regression dat
n_samples, n_features, noise = 1000, 2, 0.1
X, y = make_regression(n_samples=n_samples, n_features=n_features)

# Plot the first two dimensions of the data
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', s=10)
plt.title('Synthetic Regression Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar(label='Target Value')
plt.show()

# %%
def estimate_memory_usage(n_samples, n_features, model_type, n_inducing=None):
    # Memory for dataset (X_train and y_train)
    dataset_memory = n_samples * n_features * 8 + n_samples * 8  # X_train + y_train (float64, 8 bytes per float)
    if model_type == "GPR":
        # Full GP: Covariance matrix is N x N
        covariance_matrix_memory = n_samples ** 2 * 8  # N x N matrix, 8 bytes per float
    elif model_type == "SGPR":
        # Sparse GP: Covariance matrix is M x M (inducing points)
        if n_inducing is None:
            raise ValueError("n_inducing must be provided for SGPR")
        covariance_matrix_memory = n_inducing ** 2 * 8  # M x M matrix, 8 bytes per float
    
    # Memory for kernel parameters and gradients (assume around 1 KB for kernel + gradients)
    kernel_and_gradients_memory = 1024  # Rough estimation

    # Total memory usage estimate
    total_memory = dataset_memory + covariance_matrix_memory + kernel_and_gradients_memory

    return total_memory / (1024 ** 2)  # Convert to MB

# %%
# Function for farthest point sampling to select inducing points:
def farthest_point_sampling(X, n_inducing_points):
    
    # Start by selecting a random point from X as the first inducing point
    Z = [X[np.random.choice(len(X))]]
    
    # Iteratively select the farthest point from the set Z and and to the set
    for _ in range(n_inducing_points - 1):
        # Calculate distances from each point in X to the nearest point in Z
        dists = jnp.min(jnp.array([jnp.linalg.norm(X - z, axis=1) for z in Z]), axis=0)
        # Select the point farthest from Z and add it to the set
        next_point = X[jnp.argmax(dists)]
        Z.append(next_point)
    
    return jnp.array(Z)

# Function to train a GP model and return the RMSE, average uncertainty, time taken, and iteration count
def train_and_evaluate_gp(n_samples, model, optim_method):
    # Generate synthetic regression data
    X, y = make_regression(n_samples=n_samples, n_features=1, noise=0.1, random_state=0)  # n_features=1 for plotting
    # Split the data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # Create a GP regression model with an RBF kernel
    ''' if model == "GPR":
        model = gpf.models.GPR(data=(X_train, y_train), kernel=Kernel, mean_function=None)
    elif model == "SGPR":
        inducing_variables = tf.gather(X_train, tf.random.shuffle(tf.range(tf.shape(X_train)[0]))[:tf.shape(X_train)[0] // 10])
        model = gpf.models.SGPR(data=(X_train, y_train), kernel=Kernel, inducing_variable=inducing_variables, mean_function=None)
        gpf.config.set_default_jitter(1e-6) '''
    # Measure the time taken to optimize (which includes matrix inversion)
    start_time = time.time()
    
    # Optimize the model's parameters with a callback to count iterations
    if model == "GPR":
        model = GaussianProcess(X_train, y_train, optim_method)
    if model == "SGPR":
        n_inducing_points = int(len(X_train)*0.1)  # or any other number less than n_points
        # Z_train = X_train[np.random.choice(len(X_train), n_inducing_points, replace=False)]
        Z_train = farthest_point_sampling(X_train, n_inducing_points)
        model = SparseGaussianProcess(X_train, y_train, Z_train, optim_method)
    
    model.fit()
    
    
    end_time = time.time()
    
    # Time taken for matrix inversion and optimization
    time_taken = end_time - start_time
    
    # Retrieve and display parameter history if optimizer is ADAM
    if hasattr(model, "adam_optimizer"):
        param_history = model.adam_optimizer.param_history
        print("Parameter History:")
        #for params in param_history:
        #    print(params)
    
    # Make predictions on the test set
    means, variances = zip(*(model.predict(x.reshape(-1, 1)) for x in X_test))

    # Compute RMSE
    rmse = np.sqrt(np.mean((np.array(means) - y_test) ** 2))

    # Compute average uncertainty (standard deviation)
    avg_uncertainty = np.mean(np.sqrt(np.array(variances)))
    
    return rmse, avg_uncertainty, time_taken

# %%
import matplotlib.pyplot as plt
import numpy as np
import psutil
import time

# Utility to get memory usage
def get_memory_usage():
    process = psutil.Process()
    mem_info = process.memory_info()
    return mem_info.rss / (1024 ** 2)  # Return memory usage in MB

# General function to run comparison for multiple GP models
def run_comparison(max_samples, models_kernels):
    start = 20
    step = 10
    dataset_sizes = np.arange(start, max_samples + 1, step)

    # Dictionary to store results for each model
    results = {
        'loss_history': {},
        'times': {},
        'uncertainties': {},
        'memory_usages': {},
    }

    # Loop over each model and its kernel
    for model_name, optim_method in models_kernels:
        loss_history = []
        times = []
        uncertainties = []  
        memory_usages = []
        


        for idx, size in enumerate(dataset_sizes):
            rmse, avg_uncertainty, time_taken = train_and_evaluate_gp(size, model_name, optim_method)
            loss_history.append(rmse)
            memory = estimate_memory_usage(n_samples=size, n_features=n_features, model_type=model_name, n_inducing=0.1*size)
            uncertainties.append(avg_uncertainty)
            times.append(time_taken)
            memory_usages.append(memory)
            name = model_name + " " + optim_method
            print(f"Model: {name}, Dataset size: {size}, Time: {time_taken:.4f} seconds, "
                  f"Memory: {memory:.2f} MB,"
                  f"Uncertainty: {avg_uncertainty:.4f}")
        
        # Store results for this model
        results['times'][name] = times
        results['uncertainties'][name] = uncertainties
        results['memory_usages'][name] = memory_usages
        results['loss_history'][name] = loss_history
    
    # Plotting the results
    plt.figure(figsize=(10, 12))
    # Loss plot

    plt.subplot(4, 1, 1)
    for name in results['loss_history']:
        plt.plot(dataset_sizes, results['loss_history'][name], 'o-', label=f'{name} Loss')
    plt.title('Performance Metrics vs Dataset Size')
    plt.ylabel('Loss (RMSE)')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()
    
    # Time Plot
    plt.subplot(4, 1, 2)
    for name in results['times']:
        plt.plot(dataset_sizes, results['times'][name], 'o-', label=f'{name} Time')
    plt.title('Performance Metrics vs Dataset Size')
    plt.ylabel('Time (seconds)')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()

    # Memory Usage Plot
    plt.subplot(4, 1, 3)
    for name in results['memory_usages']:
        plt.plot(dataset_sizes, results['memory_usages'][name], 'o-', label=f'{name} Memory Usage')
    plt.ylabel('Memory Usage (MB)')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()

    # Uncertainty Plot
    plt.subplot(4, 1, 4)
    for name in results['uncertainties']:
        plt.plot(dataset_sizes, results['uncertainties'][name], 'o-', label=f'{name} Avg. Uncertainty')
    plt.ylabel('Uncertainty')
    plt.xscale('log')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

    return results

# %%
models_kernels = [
    #("GPR", "L-BFGS-B"),
    ("SGPR", "L-BFGS-B"),
    #("GPR", "CG"),
    ("SGPR", "CG"),
    #("GPR", "ADAM"),
    ("SGPR", "ADAM"),
    

]
# Run the comparison for these models
run_comparison(max_samples=100, models_kernels=models_kernels)
# Out:
# Training complete. Optimal length scale: 0.75, Signal variance: 0.95, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 20, Time: 0.8097 seconds, Memory: 0.00 MB,Uncertainty: 0.9863
# Training complete. Optimal length scale: 1.07, Signal variance: 1.27, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 30, Time: 0.4335 seconds, Memory: 0.00 MB,Uncertainty: 0.7302
# Training complete. Optimal length scale: 1.94, Signal variance: 0.20, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 40, Time: 0.5730 seconds, Memory: 0.00 MB,Uncertainty: 0.1352
# Training complete. Optimal length scale: 1.76, Signal variance: 1.55, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 50, Time: 0.7527 seconds, Memory: 0.00 MB,Uncertainty: 0.0162
# Training complete. Optimal length scale: 0.28, Signal variance: 1.61, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 60, Time: 0.8010 seconds, Memory: 0.00 MB,Uncertainty: 0.8244
# Training complete. Optimal length scale: 1.49, Signal variance: 2.78, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 70, Time: 1.2425 seconds, Memory: 0.00 MB,Uncertainty: 0.0433
# Training complete. Optimal length scale: 0.86, Signal variance: 0.70, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 80, Time: 1.5093 seconds, Memory: 0.00 MB,Uncertainty: 0.0691
# Training complete. Optimal length scale: 1.97, Signal variance: 1.95, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 90, Time: 2.0885 seconds, Memory: 0.00 MB,Uncertainty: 0.0034
# Training complete. Optimal length scale: -0.29, Signal variance: 1.51, Noise variance: 0.00
# Model: SGPR L-BFGS-B, Dataset size: 100, Time: 2.3252 seconds, Memory: 0.00 MB,Uncertainty: 0.4900
# Training complete. Optimal length scale: 0.84, Signal variance: 1.54, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 20, Time: 0.0724 seconds, Memory: 0.00 MB,Uncertainty: 0.6537
# Training complete. Optimal length scale: 0.67, Signal variance: 1.48, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 30, Time: 0.1627 seconds, Memory: 0.00 MB,Uncertainty: 0.8483
# Training complete. Optimal length scale: 1.76, Signal variance: 1.78, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 40, Time: 0.2921 seconds, Memory: 0.00 MB,Uncertainty: 0.1699
# Training complete. Optimal length scale: 1.51, Signal variance: 1.40, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 50, Time: 0.4540 seconds, Memory: 0.00 MB,Uncertainty: 0.0510
# Training complete. Optimal length scale: 1.71, Signal variance: 0.12, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 60, Time: 0.6382 seconds, Memory: 0.00 MB,Uncertainty: 0.0539
# Training complete. Optimal length scale: 1.75, Signal variance: 0.88, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 70, Time: 0.9291 seconds, Memory: 0.00 MB,Uncertainty: 0.0218
# Training complete. Optimal length scale: 0.36, Signal variance: 0.32, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 80, Time: 1.2112 seconds, Memory: 0.00 MB,Uncertainty: 0.4547
# Training complete. Optimal length scale: 0.38, Signal variance: 1.83, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 90, Time: 1.4620 seconds, Memory: 0.00 MB,Uncertainty: 0.3972
# Training complete. Optimal length scale: 0.34, Signal variance: 1.88, Noise variance: 0.00
# Model: SGPR CG, Dataset size: 100, Time: 1.9454 seconds, Memory: 0.00 MB,Uncertainty: 0.3290
# Training complete. Optimal length scale: 1.33, Signal variance: 5.82, Noise variance: 2.18
# Parameter History:
# Model: SGPR ADAM, Dataset size: 20, Time: 1.8273 seconds, Memory: 0.00 MB,Uncertainty: 1.7075
# Training complete. Optimal length scale: 0.56, Signal variance: 8.04, Noise variance: 4.30
# Parameter History:
# Model: SGPR ADAM, Dataset size: 30, Time: 1.8473 seconds, Memory: 0.00 MB,Uncertainty: 2.2923
# Training complete. Optimal length scale: 0.57, Signal variance: 6.52, Noise variance: 3.10
# Parameter History:
# Model: SGPR ADAM, Dataset size: 40, Time: 2.2082 seconds, Memory: 0.00 MB,Uncertainty: 1.9874
# Training complete. Optimal length scale: 4.81, Signal variance: 6.72, Noise variance: 3.30
# Parameter History:
# Model: SGPR ADAM, Dataset size: 50, Time: 2.2608 seconds, Memory: 0.00 MB,Uncertainty: 1.9481
# Training complete. Optimal length scale: 0.40, Signal variance: 7.11, Noise variance: 3.61
# Parameter History:
# Model: SGPR ADAM, Dataset size: 60, Time: 2.4894 seconds, Memory: 0.00 MB,Uncertainty: 2.1227
# Training complete. Optimal length scale: 1.28, Signal variance: 5.84, Noise variance: 2.31
# Parameter History:
# Model: SGPR ADAM, Dataset size: 70, Time: 2.8129 seconds, Memory: 0.00 MB,Uncertainty: 1.6925
# Training complete. Optimal length scale: 0.20, Signal variance: 6.41, Noise variance: 2.99
# Parameter History:
# Model: SGPR ADAM, Dataset size: 80, Time: 3.2199 seconds, Memory: 0.00 MB,Uncertainty: 1.9666
# Training complete. Optimal length scale: 5.41, Signal variance: 7.40, Noise variance: 3.81
# Parameter History:
# Model: SGPR ADAM, Dataset size: 90, Time: 3.9438 seconds, Memory: 0.00 MB,Uncertainty: 2.0480
# Training complete. Optimal length scale: 0.33, Signal variance: 7.83, Noise variance: 4.10
# Parameter History:
# Model: SGPR ADAM, Dataset size: 100, Time: 4.4796 seconds, Memory: 0.00 MB,Uncertainty: 2.2220
# {'loss_history': {'SGPR L-BFGS-B': [12.954769600191728,
#    100.82821330055917,
#    43.64125494041633,
#    2.1696165891483363,
#    27.28842340934659,
#    71.83140905438069,
#    78.03411554855025,
#    487.42321495406986,
#    58.35469796570106],
#   'SGPR CG': [13.075566087733675,
#    119.134544995049,
#    43.16658599516955,
#    24.99240357965268,
#    53.652400747850386,
#    72.5972332712135,
#    79.03755257169648,
#    83.94428588623614,
#    72.87329658473327],
#   'SGPR ADAM': [11.136460743523502,
#    124.11318815103856,
#    21.701725615439393,
#    9.955133788239907,
#    33.21876776844872,
#    64.88311417388643,
#    86.73611741401655,
#    87.95913992133167,
#    43.75309281589406]},
#  'times': {'SGPR L-BFGS-B': [0.8096919059753418,
#    0.43352723121643066,
#    0.5730240345001221,
#    0.7526650428771973,
#    0.8009731769561768,
#    1.2424769401550293,
#    1.5093119144439697,
#    2.0884878635406494,
#    2.3251872062683105],
#   'SGPR CG': [0.07241010665893555,
#    0.16272830963134766,
#    0.2921171188354492,
#    0.4539608955383301,
#    0.638218879699707,
#    0.9290828704833984,
#    1.2112162113189697,
#    1.4619789123535156,
#    1.9453940391540527],
#   'SGPR ADAM': [1.8273417949676514,
#    1.8472869396209717,
#    2.208164930343628,
#    2.2608282566070557,
#    2.489410877227783,
#    2.812918186187744,
#    3.2199392318725586,
#    3.9437599182128906,
#    4.479604959487915]},
#  'uncertainties': {'SGPR L-BFGS-B': [0.9863334,
#    0.73022294,
#    0.1351992,
#    0.016242065,
#    0.8244121,
#    0.04331361,
#    0.06912717,
#    0.0033514297,
#    0.48995742],
#   'SGPR CG': [0.6536885,
#    0.8482649,
#    0.16990194,
#    0.0510434,
#    0.05393276,
#    0.021810055,
#    0.45467827,
#    0.39717072,
#    0.32899386],
#   'SGPR ADAM': [1.7075146,
#    2.2923248,
#    1.987432,
#    1.9480959,
#    2.1226895,
#    1.6925192,
#    1.9666377,
#    2.0479531,
#    2.2219553]},
#  'memory_usages': {'SGPR L-BFGS-B': [0.00146484375,
#    0.00173187255859375,
#    0.00201416015625,
#    0.00231170654296875,
#    0.00262451171875,
#    0.00295257568359375,
#    0.0032958984375,
#    0.00365447998046875,
#    0.0040283203125],
#   'SGPR CG': [0.00146484375,
#    0.00173187255859375,
#    0.00201416015625,
#    0.00231170654296875,
#    0.00262451171875,
#    0.00295257568359375,
#    0.0032958984375,
#    0.00365447998046875,
#    0.0040283203125],
#   'SGPR ADAM': [0.00146484375,
#    0.00173187255859375,
#    0.00201416015625,
#    0.00231170654296875,
#    0.00262451171875,
#    0.00295257568359375,
#    0.0032958984375,
#    0.00365447998046875,
#    0.0040283203125]}}
